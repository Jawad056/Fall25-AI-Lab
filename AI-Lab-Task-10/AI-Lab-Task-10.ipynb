# %% [markdown]
# **Name: Jawad-Haider**
#
# **Roll No.: SU92-BSAIM-F24-056**
#
# **Section: BSAI-3A**
#
# **Task: 10**

# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd

# %% [markdown]
# <b>1. Data Gathering</b> : <a href="https://www.kaggle.com/datasets/mamunhasan2cs/student-academic-performance-synthetic-dataset?resource=download"> DataSet from Kaggle </a>

# %% [markdown]
# **2. Data Loading**

# %%
df = pd.read_csv("student_performance.csv")
df
# Out:
#      Student_ID  Age  Gender  Study_Hours  Attendance(%)  Test_Score Grade
# 0         S0524   21  Female          NaN           74.0          37     F
# 1         S0603   19    Male          1.5           93.1          26     F
# 2         S0527   20  Female          6.8           97.2          88     A
# 3         S0032   18  Female          6.2           93.5          55     C
# 4         S0617   21    Male          7.4           99.2          77     B
# ...         ...  ...     ...          ...            ...         ...   ...
# 1015      S0107   22  Female          6.3           84.7          72     B
# 1016      S0271   22    Male          5.3          100.5          45     F
# 1017      S0861   21  Female          4.0          102.7          30     F
# 1018      S0436   18  Female          6.3           92.4          55     C
# 1019      S0103   21  Female          1.6            NaN          37     F
#
# [1020 rows x 7 columns]

# %%
df['Attendance(%)'] = df['Attendance(%)'].clip(upper=100)

# %%
df
# Out:
#      Student_ID  Age  Gender  Study_Hours  Attendance(%)  Test_Score Grade
# 0         S0524   21  Female          NaN           74.0          37     F
# 1         S0603   19    Male          1.5           93.1          26     F
# 2         S0527   20  Female          6.8           97.2          88     A
# 3         S0032   18  Female          6.2           93.5          55     C
# 4         S0617   21    Male          7.4           99.2          77     B
# ...         ...  ...     ...          ...            ...         ...   ...
# 1015      S0107   22  Female          6.3           84.7          72     B
# 1016      S0271   22    Male          5.3          100.0          45     F
# 1017      S0861   21  Female          4.0          100.0          30     F
# 1018      S0436   18  Female          6.3           92.4          55     C
# 1019      S0103   21  Female          1.6            NaN          37     F
#
# [1020 rows x 7 columns]

# %% [markdown]
# **3. Data Exploration**

# %%
df.head()
# Out:
#   Student_ID  Age  Gender  Study_Hours  Attendance(%)  Test_Score Grade
# 0      S0524   21  Female          NaN           74.0          37     F
# 1      S0603   19    Male          1.5           93.1          26     F
# 2      S0527   20  Female          6.8           97.2          88     A
# 3      S0032   18  Female          6.2           93.5          55     C
# 4      S0617   21    Male          7.4           99.2          77     B

# %%
df.tail()
# Out:
#      Student_ID  Age  Gender  Study_Hours  Attendance(%)  Test_Score Grade
# 1015      S0107   22  Female          6.3           84.7          72     B
# 1016      S0271   22    Male          5.3          100.0          45     F
# 1017      S0861   21  Female          4.0          100.0          30     F
# 1018      S0436   18  Female          6.3           92.4          55     C
# 1019      S0103   21  Female          1.6            NaN          37     F

# %%
df.columns

for i in df.columns:
    print(i)
# Out:
# Student_ID
# Age
# Gender
# Study_Hours
# Attendance(%)
# Test_Score
# Grade

# %%
df.count()
# Out:
# Student_ID       1020
# Age              1020
# Gender           1020
# Study_Hours       988
# Attendance(%)     989
# Test_Score       1020
# Grade            1011
# dtype: int64

# %%
df.describe()
# Out:
#                Age  Study_Hours  Attendance(%)   Test_Score
# count  1020.000000   988.000000     989.000000  1020.000000
# mean     20.970588     5.163259      84.606269    49.843137
# std       2.008109     2.555970       9.514239    21.278630
# min      18.000000    -2.000000      50.300000     0.000000
# 25%      19.000000     3.700000      78.000000    35.000000
# 50%      21.000000     5.100000      85.000000    50.000000
# 75%      23.000000     6.325000      91.900000    64.000000
# max      24.000000    25.000000     100.000000   100.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Student_ID     1020 non-null   object
#  1   Age            1020 non-null   int64
#  2   Gender         1020 non-null   object
#  3   Study_Hours    988 non-null    float64
#  4   Attendance(%)  989 non-null    float64
#  5   Test_Score     1020 non-null   int64
#  6   Grade          1011 non-null   object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 55.9+ KB

# %%
df.shape
print(f"Number of Rows: {df.shape[0]} and Number of Columns: {df.shape[1]}")
# Out:
# Number of Rows: 1020 and Number of Columns: 7

# %%
df['Age'].unique()
# Out:
# array([21, 19, 20, 18, 23, 22, 24])

# %%
df.nunique()
# Out:
# Student_ID       1000
# Age                 7
# Gender              2
# Study_Hours       106
# Attendance(%)     323
# Test_Score        101
# Grade               5
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Student_ID        0
# Age               0
# Gender            0
# Study_Hours      32
# Attendance(%)    31
# Test_Score        0
# Grade             9
# dtype: int64

# %% [markdown]
# 4. **Data Pre-Processing**

# %%
# Fill numeric columns with mean (safe way)
df['Study_Hours'] = df['Study_Hours'].fillna(df['Study_Hours'].mean())
df['Attendance(%)'] = df['Attendance(%)'].fillna(df['Attendance(%)'].mean())
df['Test_Score'] = df['Test_Score'].fillna(df['Test_Score'].mean())

# Fill categorical columns with mode
df['Gender'] = df['Gender'].fillna(df['Gender'].mode()[0])
df['Grade'] = df['Grade'].fillna(df['Grade'].mode()[0])

# Verify no more nulls
print(df.isnull().sum())
# Out:
# Student_ID       0
# Age              0
# Gender           0
# Study_Hours      0
# Attendance(%)    0
# Test_Score       0
# Grade            0
# dtype: int64

# %%
# Convert to integer (round first if needed)
df['Age'] = df['Age'].astype(int)
df['Study_Hours'] = df['Study_Hours'].round().astype(int)
df['Attendance(%)'] = df['Attendance(%)'].round().astype(int)
df['Test_Score'] = df['Test_Score'].astype(int)

# Verify datatypes
print(df.dtypes)
# Out:
# Student_ID       object
# Age               int64
# Gender           object
# Study_Hours       int64
# Attendance(%)     int64
# Test_Score        int64
# Grade            object
# dtype: object

# %%
# Encode Gender: Female=0, Male=1
df['Gender'] = df['Gender'].map({'Female': 0, 'Male': 1})

# Encode Grade: F=0, C=1, B=2, A=3
df['Grade'] = df['Grade'].map({'F': 0, 'C': 1, 'B': 2, 'A': 3})

print(df.head())
# Out:
#   Student_ID  Age  Gender  Study_Hours  Attendance(%)  Test_Score  Grade
# 0      S0524   21       0            5             74          37    0.0
# 1      S0603   19       1            2             93          26    0.0
# 2      S0527   20       0            7             97          88    3.0
# 3      S0032   18       0            6             94          55    1.0
# 4      S0617   21       1            7             99          77    2.0
